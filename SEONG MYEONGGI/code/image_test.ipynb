# %%
import os
import numpy as np
import matplotlib.pyplot as plt

# %%
data = os.listdir('/home/data/train/')

# %%
# /home/data/train/0a1b8d3c52d64052.jpg 열기
img = plt.imread('/home/data/train/0a1b8d3c52d64052.jpg')
plt.imshow(img)

# %%
import numpy as np
from PIL import Image
import cv2
import os

# median blur
median_blur_img = cv2.medianBlur(img, 7)
plt.imshow(median_blur_img)

# %%
# Gaussian noise
img = cv2.imread('/home/data/train/0a1b8d3c52d64052.jpg')
contrast_img = cv2.convertScaleAbs(img, alpha=3.0, beta=10)
plt.imshow(contrast_img)

# %%
from rembg import remove

def remove_img():
    img = '0a1b8d3c52d64052'
    input_img = plt.imread(f'/home/data/train/{img}.jpg')
    output_img = f'/home/data/rembg_img/{img}_rembg.png'
    input = Image.open(input_img)
    output = remove(input)
    output.save(output)
    
remove_img()

# %%
from rembg import remove

def remove_img():
    img = '0a1b8d3c52d64052'
    input_img_path = f'/home/data/train/{img}.jpg'
    output_img_path = f'/home/data/rembg_img/{img}_rembg.png'
    input = Image.open(input_img_path)
    output = remove(input)
    output.save(output_img_path)
    
remove_img()
