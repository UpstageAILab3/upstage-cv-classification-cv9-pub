# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import os
from skimage import io, img_as_float, img_as_ubyte
from skimage.transform import resize
from torch.utils.data import Dataset, DataLoader
from tqdm import tqdm
import pandas as pd
import gc
import random

# 시드 설정
seed = 42
random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)
if torch.cuda.is_available():
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False



# DnCNN 모델 정의
class DnCNN(nn.Module):
    def __init__(self, channels=1, num_of_layers=17):
        super(DnCNN, self).__init__()
        kernel_size = 3
        padding = 1
        features = 64
        layers = []
        layers.append(nn.Conv2d(in_channels=channels, out_channels=features, kernel_size=kernel_size, padding=padding, bias=False))
        layers.append(nn.ReLU(inplace=True))
        for _ in range(num_of_layers - 2):
            layers.append(nn.Conv2d(in_channels=features, out_channels=features, kernel_size=kernel_size, padding=padding, bias=False))
            layers.append(nn.BatchNorm2d(features))
            layers.append(nn.ReLU(inplace=True))
        layers.append(nn.Conv2d(in_channels=features, out_channels=channels, kernel_size=kernel_size, padding=padding, bias=False))
        self.dncnn = nn.Sequential(*layers)

    def forward(self, x):
        out = self.dncnn(x)
        return x - out

# 데이터셋 클래스 정의
class NoisyImageDataset(Dataset):
    def __init__(self, csv_file, root_dir, transform=None):
        self.annotations = pd.read_csv(csv_file)
        self.root_dir = root_dir
        self.transform = transform
    
    def __len__(self):
        return len(self.annotations)
    
    def __getitem__(self, idx):
        img_name = os.path.join(self.root_dir, self.annotations.iloc[idx, 0])
        image = img_as_float(io.imread(img_name))
        image = resize(image, (224, 224), anti_aliasing=True)
        noise = np.random.normal(0, 25/255, image.shape)
        noisy_image = image + noise
        noisy_image = np.clip(noisy_image, 0, 1)
        
        if self.transform:
            noisy_image = self.transform(noisy_image)
            image = self.transform(image)
        
        return noisy_image, image

# 모델 학습 함수 정의
def train_model(model, dataloader, criterion, optimizer, device, num_epochs=5):
    model.train()
    for epoch in range(num_epochs):
        running_loss = 0.0
        for noisy_images, clean_images in tqdm(dataloader):
            noisy_images = noisy_images.permute(0, 3, 1, 2).float().to(device)
            clean_images = clean_images.permute(0, 3, 1, 2).float().to(device)
            
            outputs = model(noisy_images)
            loss = criterion(outputs, clean_images)
            
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            
            running_loss += loss.item() * noisy_images.size(0)
        
        epoch_loss = running_loss / len(dataloader.dataset)
        print(f'Epoch {epoch+1}/{num_epochs}, Loss: {epoch_loss:.4f}')

# 모델 디노이징 함수 정의
def denoise_image(model, image, device):
    image = img_as_float(image)
    image = resize(image, (224, 224), anti_aliasing=True)
    input_tensor = torch.from_numpy(image).permute(2, 0, 1).unsqueeze(0).float().to(device)
    with torch.no_grad():
        output_tensor = model(input_tensor)
    output_image = output_tensor.squeeze(0).permute(1, 2, 0).cpu().numpy()
    output_image = np.clip(output_image, 0, 1)
    output_image = img_as_ubyte(output_image)
    return output_image

# 디바이스 설정 (GPU 사용 여부)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f'Using device: {device}')
# Out:
# Using device: cuda

# %%
# 데이터셋 및 데이터로더 준비
csv_file = 'cv_challenge/train_augmented_byteam_rf_and_original.csv'
root_dir = 'cv_challenge/data_argumentation_byteam_rotate_flipped'
dataset = NoisyImageDataset(csv_file=csv_file, root_dir=root_dir)
dataloader = DataLoader(dataset, batch_size=4, shuffle=True)

# 모델, 손실 함수 및 옵티마이저 설정
model = DnCNN(channels=3).to(device)
criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# 모델 학습
train_model(model, dataloader, criterion, optimizer, device, num_epochs=5)

# 디노이징 적용
test_image_folder = "cv_challenge/test"
output_image_folder = "cv_challenge/denoised_images"

if not os.path.exists(output_image_folder):
    os.makedirs(output_image_folder)

test_images = [f for f in os.listdir(test_image_folder) if os.path.isfile(os.path.join(test_image_folder, f))]

for image_name in test_images:
    image_path = os.path.join(test_image_folder, image_name)
    image = io.imread(image_path)
    
    denoised_image = denoise_image(model, image, device)
    
    output_image_path = os.path.join(output_image_folder, image_name)
    io.imsave(output_image_path, denoised_image)
    print(f"Denoised image saved to {output_image_path}")
# Out:
# 100%|██████████| 6280/6280 [1:22:57<00:00,  1.26it/s]
# Epoch 1/5, Loss: 0.0043
# 100%|██████████| 6280/6280 [1:45:37<00:00,  1.01s/it]
# Epoch 2/5, Loss: 0.0007
# 100%|██████████| 6280/6280 [1:28:37<00:00,  1.18it/s]
# Epoch 3/5, Loss: 0.0008
# 100%|██████████| 6280/6280 [1:15:16<00:00,  1.39it/s]
# Epoch 4/5, Loss: 0.0012
# 100%|██████████| 6280/6280 [1:14:46<00:00,  1.40it/s]
# Epoch 5/5, Loss: 0.0005
# Denoised image saved to cv_challenge/denoised_images\0008fdb22ddce0ce.jpg
# Denoised image saved to cv_challenge/denoised_images\00091bffdffd83de.jpg
# Denoised image saved to cv_challenge/denoised_images\00396fbc1f6cc21d.jpg
# Denoised image saved to cv_challenge/denoised_images\00471f8038d9c4b6.jpg
# Denoised image saved to cv_challenge/denoised_images\00901f504008d884.jpg
# Denoised image saved to cv_challenge/denoised_images\009b22decbc7220c.jpg
# Denoised image saved to cv_challenge/denoised_images\00b33e0ee6d59427.jpg
# Denoised image saved to cv_challenge/denoised_images\00bbdcfbbdb3e131.jpg
# Denoised image saved to cv_challenge/denoised_images\00c03047e0fbef40.jpg
# Denoised image saved to cv_challenge/denoised_images\00c0dabb63ca7a16.jpg
# Denoised image saved to cv_challenge/denoised_images\00dcea90f63ad630.jpg
# Denoised image saved to cv_challenge/denoised_images\00e15da96484eb94.jpg
# Denoised image saved to cv_challenge/denoised_images\00f5784903a39fdd.jpg
# Denoised image saved to cv_challenge/denoised_images\0111a6728e9f8a73.jpg
# Denoised image saved to cv_challenge/denoised_images\0114a887a2c2e4ca.jpg
# Denoised image saved to cv_challenge/denoised_images\01385f22f2490868.jpg
# Denoised image saved to cv_challenge/denoised_images\0145dd3d1cd090ae.jpg
# Denoised image saved to cv_challenge/denoised_images\016240faa186d24d.jpg
# Denoised image saved to cv_challenge/denoised_images\016b0c00cdf93e0a.jpg
# Denoised image saved to cv_challenge/denoised_images\017ba667291b53c6.jpg
# Denoised image saved to cv_challenge/denoised_images\017e5da799e1637c.jpg
# Denoised image saved to cv_challenge/denoised_images\0182bffa56bdd844.jpg
# Denoised image saved to cv_challenge/denoised_images\019ed42bb4c2caa9.jpg
# Denoised image saved to cv_challenge/denoised_images\01bd84a54be54b8b.jpg
# Denoised image saved to cv_challenge/denoised_images\01c918594307c6f2.jpg
# Denoised image saved to cv_challenge/denoised_images\01ebd05a14e10618.jpg
# Denoised image saved to cv_challenge/denoised_images\020740b55bbc329e.jpg
# Denoised image saved to cv_challenge/denoised_images\021e7c8d9dc19021.jpg
# Denoised image saved to cv_challenge/denoised_images\0298c2151b43d86b.jpg
# Denoised image saved to cv_challenge/denoised_images\02ac23941313841b.jpg
# Denoised image saved to cv_challenge/denoised_images\02b370d53ff25d45.jpg
# Denoised image saved to cv_challenge/denoised_images\02b3712bd48b8644.jpg
# Denoised image saved to cv_challenge/denoised_images\02b5e73920c3c54e.jpg
# Denoised image saved to cv_challenge/denoised_images\02f79963274b3c41.jpg
# Denoised image saved to cv_challenge/denoised_images\02ffc27eff468793.jpg
# Denoised image saved to cv_challenge/denoised_images\0366fcb21245a5cc.jpg
# Denoised image saved to cv_challenge/denoised_images\039ff76910d52749.jpg
# Denoised image saved to cv_challenge/denoised_images\03a7dcbe6b74bb8e.jpg
# Denoised image saved to cv_challenge/denoised_images\03cb3f2e0962474e.jpg
# Denoised image saved to cv_challenge/denoised_images\040ba9bc68f4e380.jpg
# Denoised image saved to cv_challenge/denoised_images\0412f6a5ba912add.jpg
# Denoised image saved to cv_challenge/denoised_images\04284576791e9ec1.jpg
# Denoised image saved to cv_challenge/denoised_images\0447bde0b7da3a6c.jpg
# Denoised image saved to cv_challenge/denoised_images\046c2f2d42bbac35.jpg
# Denoised image saved to cv_challenge/denoised_images\048efa3d18a4999d.jpg
# Denoised image saved to cv_challenge/denoised_images\048fe083d6a62591.jpg
# Denoised image saved to cv_challenge/denoised_images\04917bb8d098898f.jpg
# Denoised image saved to cv_challenge/denoised_images\049445f90a8a2b8d.jpg
# Denoised image saved to cv_challenge/denoised_images\04f502c69bb8dcaa.jpg
# Denoised image saved to cv_challenge/denoised_images\04fc58802ef2f7a6.jpg
# Denoised image saved to cv_challenge/denoised_images\05050540613224a2.jpg
# Denoised image saved to cv_challenge/denoised_images\050d88c14e0ea5f9.jpg
# Denoised image saved to cv_challenge/denoised_images\050e27e8c616e585.jpg
# Denoised image saved to cv_challenge/denoised_images\05426a351b09c757.jpg
# Denoised image saved to cv_challenge/denoised_images\0546cab14c4ee65b.jpg
# Denoised image saved to cv_challenge/denoised_images\0567d092e87d347c.jpg
# Denoised image saved to cv_challenge/denoised_images\0575671b2c5b34ad.jpg
# Denoised image saved to cv_challenge/denoised_images\05e33cb53c1ac02a.jpg
# Denoised image saved to cv_challenge/denoised_images\05f1039b7cbffe72.jpg
# Denoised image saved to cv_challenge/denoised_images\0639e3932c5f7817.jpg
# Denoised image saved to cv_challenge/denoised_images\06427235c81111cc.jpg
# Denoised image saved to cv_challenge/denoised_images\0689f795bd5627e1.jpg
# Denoised image saved to cv_challenge/denoised_images\068f74f7f3021444.jpg
# Denoised image saved to cv_challenge/denoised_images\06948b8091b11d1c.jpg
# Denoised image saved to cv_challenge/denoised_images\06a484eb2afab068.jpg
# Denoised image saved to cv_challenge/denoised_images\06df33e924e78422.jpg
# Denoised image saved to cv_challenge/denoised_images\06df57c67fcc47f4.jpg
# Denoised image saved to cv_challenge/denoised_images\06fb9852b074f191.jpg
# Denoised image saved to cv_challenge/denoised_images\070f663641adc8c5.jpg
# Denoised image saved to cv_challenge/denoised_images\0716d938d4ee1685.jpg
# Denoised image saved to cv_challenge/denoised_images\071a06f75055347b.jpg
# Denoised image saved to cv_challenge/denoised_images\071d8072ab53ecf5.jpg
# Denoised image saved to cv_challenge/denoised_images\072731843ae064a6.jpg
# Denoised image saved to cv_challenge/denoised_images\073b706bf2450eff.jpg
# Denoised image saved to cv_challenge/denoised_images\075ed6e4c487debc.jpg
# Denoised image saved to cv_challenge/denoised_images\0778027c660394b0.jpg
# Denoised image saved to cv_challenge/denoised_images\0793d5249a3b298e.jpg
# Denoised image saved to cv_challenge/denoised_images\07a5f3b6e75f9caf.jpg
# Denoised image saved to cv_challenge/denoised_images\07bc5cc66ff8caee.jpg
# Denoised image saved to cv_challenge/denoised_images\07d545e9eafadf0a.jpg
# Denoised image saved to cv_challenge/denoised_images\07f6f15c8165caa4.jpg
# Denoised image saved to cv_challenge/denoised_images\080be7a4c550641c.jpg
# Denoised image saved to cv_challenge/denoised_images\0827b6ab0fe72b16.jpg
# Denoised image saved to cv_challenge/denoised_images\082e8c4d8d82eb01.jpg
# Denoised image saved to cv_challenge/denoised_images\083b515f19482696.jpg
# Denoised image saved to cv_challenge/denoised_images\083b72fc1d2da17e.jpg
# Denoised image saved to cv_challenge/denoised_images\08590b0bed418283.jpg
# Denoised image saved to cv_challenge/denoised_images\086206b3a6bc8ac7.jpg
# Denoised image saved to cv_challenge/denoised_images\086be978e8e322c9.jpg
# Denoised image saved to cv_challenge/denoised_images\087764f5ad00bd96.jpg
# Denoised image saved to cv_challenge/denoised_images\087e0c1c6e93bbc5.jpg
# Denoised image saved to cv_challenge/denoised_images\08bf436664359a17.jpg
# Denoised image saved to cv_challenge/denoised_images\08f41aac91eb8bc7.jpg
# Denoised image saved to cv_challenge/denoised_images\08f54448041c90b1.jpg
# Denoised image saved to cv_challenge/denoised_images\09194a475da4ddcc.jpg
# Denoised image saved to cv_challenge/denoised_images\091ab5500f1ff9b6.jpg
# Denoised image saved to cv_challenge/denoised_images\09297ad7ec71f908.jpg
# Denoised image saved to cv_challenge/denoised_images\092f91fcb580f212.jpg
# Denoised image saved to cv_challenge/denoised_images\09447bf11a0500aa.jpg
# Denoised image saved to cv_challenge/denoised_images\095d28682e8981f7.jpg
# Denoised image saved to cv_challenge/denoised_images\098f7da78695260d.jpg
# Denoised image saved to cv_challenge/denoised_images\099398ecd1bcf6bd.jpg
# Denoised image saved to cv_challenge/denoised_images\09a30d4d88601933.jpg
# Denoised image saved to cv_challenge/denoised_images\09db80dc3d186a2e.jpg
# Denoised image saved to cv_challenge/denoised_images\09eb83058248f2ac.jpg
# Denoised image saved to cv_challenge/denoised_images\09f1aee1561b8b0f.jpg
# Denoised image saved to cv_challenge/denoised_images\09f8b34f1e3e5743.jpg
# Denoised image saved to cv_challenge/denoised_images\0a0302cbe2dcdd40.jpg
# Denoised image saved to cv_challenge/denoised_images\0a12d28777501f71.jpg
# Denoised image saved to cv_challenge/denoised_images\0a43350242357a3a.jpg
# Denoised image saved to cv_challenge/denoised_images\0a46d57f7a0b0407.jpg
# Denoised image saved to cv_challenge/denoised_images\0a4f2decf34d3bff.jpg
# Denoised image saved to cv_challenge/denoised_images\0a5bf6ba56f069c5.jpg
# Denoised image saved to cv_challenge/denoised_images\0a95b7e3f2bdc376.jpg
# Denoised image saved to cv_challenge/denoised_images\0abb9be9652035f2.jpg
# Denoised image saved to cv_challenge/denoised_images\0aed5278485aad7d.jpg
# Denoised image saved to cv_challenge/denoised_images\0af2da38454cd083.jpg
# Denoised image saved to cv_challenge/denoised_images\0b0e7e754b5a103c.jpg
# Denoised image saved to cv_challenge/denoised_images\0b0f8f84d1b2ae04.jpg
# Denoised image saved to cv_challenge/denoised_images\0b0fd1e0a11db156.jpg
# Denoised image saved to cv_challenge/denoised_images\0b14fad2ead8cbea.jpg
# Denoised image saved to cv_challenge/denoised_images\0b255faf6658e0fa.jpg
# Denoised image saved to cv_challenge/denoised_images\0b269edda9d67e70.jpg
# Denoised image saved to cv_challenge/denoised_images\0b365c5adf7f7578.jpg
# Denoised image saved to cv_challenge/denoised_images\0b44a2ab47ec95eb.jpg
# Denoised image saved to cv_challenge/denoised_images\0b49d225b1648438.jpg
# Denoised image saved to cv_challenge/denoised_images\0b60e9d39b43e0b9.jpg
# Denoised image saved to cv_challenge/denoised_images\0b8426f6b3d9d4a3.jpg
# Denoised image saved to cv_challenge/denoised_images\0b848234702391ca.jpg
# Denoised image saved to cv_challenge/denoised_images\0b9483ad39e27019.jpg
# Denoised image saved to cv_challenge/denoised_images\0b9c5f11b9c2e742.jpg
# Denoised image saved to cv_challenge/denoised_images\0c0db67cbd783708.jpg
# Denoised image saved to cv_challenge/denoised_images\0c201bfd63ecf0a5.jpg
# Denoised image saved to cv_challenge/denoised_images\0c2de472d06705a4.jpg
# Denoised image saved to cv_challenge/denoised_images\0c44cd95b0d95b10.jpg
# Denoised image saved to cv_challenge/denoised_images\0c471a246d7c7777.jpg
# Denoised image saved to cv_challenge/denoised_images\0c5b6caa96ec9882.jpg
# Denoised image saved to cv_challenge/denoised_images\0c62c4ec8d5042a7.jpg
# Denoised image saved to cv_challenge/denoised_images\0c7c3129349c252b.jpg
# Denoised image saved to cv_challenge/denoised_images\0c86e1a3fe94b2b4.jpg
# Denoised image saved to cv_challenge/denoised_images\0c8d4f489a7d9b78.jpg
# Denoised image saved to cv_challenge/denoised_images\0c8fb4bcbb776183.jpg
# Denoised image saved to cv_challenge/denoised_images\0ca4d10967304b77.jpg
# Denoised image saved to cv_challenge/denoised_images\0ca5c5bcdd6ccf63.jpg
# Denoised image saved to cv_challenge/denoised_images\0cbc0730650db913.jpg
# Denoised image saved to cv_challenge/denoised_images\0cff25caaa6fafa1.jpg
# Denoised image saved to cv_challenge/denoised_images\0d2833d1992b660a.jpg
# Denoised image saved to cv_challenge/denoised_images\0d983587d59ea6f9.jpg
# Denoised image saved to cv_challenge/denoised_images\0d990e7791b3cef6.jpg
# Denoised image saved to cv_challenge/denoised_images\0da34c2cca958ac1.jpg
# Denoised image saved to cv_challenge/denoised_images\0dca6453aea515b9.jpg
# Denoised image saved to cv_challenge/denoised_images\0df3535e77995185.jpg
# Denoised image saved to cv_challenge/denoised_images\0df41321b2dc9b68.jpg
# Denoised image saved to cv_challenge/denoised_images\0df499833d8ec828.jpg
# Denoised image saved to cv_challenge/denoised_images\0e152632a87fcec0.jpg
# Denoised image saved to cv_challenge/denoised_images\0e181a7b2c470569.jpg
# Denoised image saved to cv_challenge/denoised_images\0e4784ef454b4db0.jpg
# Denoised image saved to cv_challenge/denoised_images\0e6ff16ce4b47fe8.jpg
# Denoised image saved to cv_challenge/denoised_images\0e82d902e8be0e62.jpg
# Denoised image saved to cv_challenge/denoised_images\0ea1c5cc98714405.jpg
# Denoised image saved to cv_challenge/denoised_images\0ea4dcbe11fc58d2.jpg
# Denoised image saved to cv_challenge/denoised_images\0eb46afcaadad03a.jpg
# Denoised image saved to cv_challenge/denoised_images\0eba2850c75c48d2.jpg
# Denoised image saved to cv_challenge/denoised_images\0eda817efb4aa013.jpg
# Denoised image saved to cv_challenge/denoised_images\0edc89f8e4b669a6.jpg
# Denoised image saved to cv_challenge/denoised_images\0f00c6aad3b537de.jpg
# Denoised image saved to cv_challenge/denoised_images\0f279185fdc162fc.jpg
# Denoised image saved to cv_challenge/denoised_images\0f28152f1258ee40.jpg
# Denoised image saved to cv_challenge/denoised_images\0f3bedf01f25f064.jpg
# Denoised image saved to cv_challenge/denoised_images\0f7c03d2cdf0979c.jpg
# Denoised image saved to cv_challenge/denoised_images\0f8f83e4c0643ffd.jpg
# Denoised image saved to cv_challenge/denoised_images\0f924f5aab23e65c.jpg
# Denoised image saved to cv_challenge/denoised_images\0fa30d89872cbb63.jpg
# Denoised image saved to cv_challenge/denoised_images\0fb80e7e918154b7.jpg
# Denoised image saved to cv_challenge/denoised_images\0fc919fba9dc77b6.jpg
# Denoised image saved to cv_challenge/denoised_images\0fd75524dfaeef7e.jpg
# Denoised image saved to cv_challenge/denoised_images\0fe35a690cfc3d47.jpg
# Denoised image saved to cv_challenge/denoised_images\0feb5fce885f15a4.jpg
# Denoised image saved to cv_challenge/denoised_images\1024f408d288354b.jpg
# Denoised image saved to cv_challenge/denoised_images\1027d7b85da774e4.jpg
# Denoised image saved to cv_challenge/denoised_images\103000fee9095f1a.jpg
# Denoised image saved to cv_challenge/denoised_images\1035f79046d7a343.jpg
# Denoised image saved to cv_challenge/denoised_images\104b4ae18d528f85.jpg
# Denoised image saved to cv_challenge/denoised_images\105a537c0ffcf2af.jpg
# Denoised image saved to cv_challenge/denoised_images\1063d3cf9de5cc41.jpg
# Denoised image saved to cv_challenge/denoised_images\106e817be539b3e7.jpg
# Denoised image saved to cv_challenge/denoised_images\10810eb0c6dddb1c.jpg
# Denoised image saved to cv_challenge/denoised_images\1081c0c3388d84de.jpg
# Denoised image saved to cv_challenge/denoised_images\10a0009b0ccbceb9.jpg
# Denoised image saved to cv_challenge/denoised_images\10b293fb79454626.jpg
# Denoised image saved to cv_challenge/denoised_images\10b350a87c7fc903.jpg
# Denoised image saved to cv_challenge/denoised_images\10b951d45cab812b.jpg
# Denoised image saved to cv_challenge/denoised_images\10c4421ecc4767d5.jpg
# Denoised image saved to cv_challenge/denoised_images\10d7dffe3a34c770.jpg
# Denoised image saved to cv_challenge/denoised_images\10f7a181195be840.jpg
# Denoised image saved to cv_challenge/denoised_images\10fdbe2e30df7d8b.jpg
# Denoised image saved to cv_challenge/denoised_images\1118b4547007c942.jpg
# Denoised image saved to cv_challenge/denoised_images\115d7f2ffef55b9f.jpg
# Denoised image saved to cv_challenge/denoised_images\117795b5057bd15e.jpg
# Denoised image saved to cv_challenge/denoised_images\117fa2615c4f1357.jpg
# Denoised image saved to cv_challenge/denoised_images\119e93dac25c2db4.jpg
# Denoised image saved to cv_challenge/denoised_images\11a1afb65afc47f3.jpg
# Denoised image saved to cv_challenge/denoised_images\11adc81590a1f617.jpg
# Denoised image saved to cv_challenge/denoised_images\11b5fec846ed1ff7.jpg
# Denoised image saved to cv_challenge/denoised_images\11d50d6089328329.jpg
# Denoised image saved to cv_challenge/denoised_images\11d514ca1791608f.jpg
# Denoised image saved to cv_challenge/denoised_images\11f8879b754f6ea9.jpg
# Denoised image saved to cv_challenge/denoised_images\1201a2dd9b5eb586.jpg
# Denoised image saved to cv_challenge/denoised_images\120ce9e055bcdc5e.jpg
# Denoised image saved to cv_challenge/denoised_images\12204163a937e519.jpg
# Denoised image saved to cv_challenge/denoised_images\122cf870061859da.jpg
# Denoised image saved to cv_challenge/denoised_images\124aa8334826cb3c.jpg
# Denoised image saved to cv_challenge/denoised_images\1276e19dfa47adc4.jpg
# Denoised image saved to cv_challenge/denoised_images\128fd89fa359e4e8.jpg
# Denoised image saved to cv_challenge/denoised_images\129e9b82a833871a.jpg
# Denoised image saved to cv_challenge/denoised_images\12aa7e3f97fad5c6.jpg
# Denoised image saved to cv_challenge/denoised_images\12b74d0884c1c88d.jpg
# Denoised image saved to cv_challenge/denoised_images\12c0ac56836761e0.jpg
# Denoised image saved to cv_challenge/denoised_images\12d3032c9cac7869.jpg
# Denoised image saved to cv_challenge/denoised_images\12f39c128bf5f434.jpg
# Denoised image saved to cv_challenge/denoised_images\12f9326335cb3683.jpg
# Denoised image saved to cv_challenge/denoised_images\12fbb2ca8a82ed41.jpg
# Denoised image saved to cv_challenge/denoised_images\12fbf7fdc82328fc.jpg
# Denoised image saved to cv_challenge/denoised_images\13602c1dd84b0810.jpg
# Denoised image saved to cv_challenge/denoised_images\1369f0112818d48d.jpg
# Denoised image saved to cv_challenge/denoised_images\137fa0da832cf39a.jpg
# Denoised image saved to cv_challenge/denoised_images\1392df37aecbb878.jpg
# Denoised image saved to cv_challenge/denoised_images\139face231a6a5ca.jpg
# Denoised image saved to cv_challenge/denoised_images\13a1310b57a45515.jpg
# Denoised image saved to cv_challenge/denoised_images\13a57c95db160dfb.jpg
# Denoised image saved to cv_challenge/denoised_images\13a9778867e2b177.jpg
# Denoised image saved to cv_challenge/denoised_images\13dec63232cbf27c.jpg
# Denoised image saved to cv_challenge/denoised_images\140ad84d3ef9ed0b.jpg
# Denoised image saved to cv_challenge/denoised_images\14198852bc1a5fb7.jpg
# Denoised image saved to cv_challenge/denoised_images\141b73b47ddd1f3b.jpg
# Denoised image saved to cv_challenge/denoised_images\1421fb31607c5123.jpg
# Denoised image saved to cv_challenge/denoised_images\1426586d3c63f747.jpg
# Denoised image saved to cv_challenge/denoised_images\142d45fde6392c14.jpg
# Denoised image saved to cv_challenge/denoised_images\14601b72560b44ce.jpg
# Denoised image saved to cv_challenge/denoised_images\147322c3f7861963.jpg
# Denoised image saved to cv_challenge/denoised_images\1499f9b7193c15fe.jpg
# Denoised image saved to cv_challenge/denoised_images\14bff117ad4c9bd5.jpg
# Denoised image saved to cv_challenge/denoised_images\14c95cf667fcb833.jpg
# Denoised image saved to cv_challenge/denoised_images\14d34cf0135baa6e.jpg
# Denoised image saved to cv_challenge/denoised_images\14d80c5f3979c24b.jpg
# Denoised image saved to cv_challenge/denoised_images\14e0947f6412bf0a.jpg
# Denoised image saved to cv_challenge/denoised_images\14ec8dda255c99ad.jpg
# Denoised image saved to cv_challenge/denoised_images\153a93981fa2a51b.jpg
# Denoised image saved to cv_challenge/denoised_images\158af3be0cb5c17c.jpg
# Denoised image saved to cv_challenge/denoised_images\1593fab57945c546.jpg
# Denoised image saved to cv_challenge/denoised_images\15a24e3d9d781c17.jpg
# Denoised image saved to cv_challenge/denoised_images\15ca73556389df7e.jpg
# Denoised image saved to cv_challenge/denoised_images\15d368bbb994e331.jpg
# Denoised image saved to cv_challenge/denoised_images\15d6890b32a3491a.jpg
# Denoised image saved to cv_challenge/denoised_images\15d8e28fa134e037.jpg
# Denoised image saved to cv_challenge/denoised_images\15e4045d87b5e34c.jpg
# Denoised image saved to cv_challenge/denoised_images\15efe59b41f3ccc7.jpg
# Denoised image saved to cv_challenge/denoised_images\163409dfa90b4918.jpg
# Denoised image saved to cv_challenge/denoised_images\1638d8b30b2a013e.jpg
# Denoised image saved to cv_challenge/denoised_images\163ff887c52871d6.jpg
# Denoised image saved to cv_challenge/denoised_images\1659601b11744f1b.jpg
# Denoised image saved to cv_challenge/denoised_images\168845a16c3ad7b5.jpg
# Denoised image saved to cv_challenge/denoised_images\16c93473c8c98b30.jpg
# Denoised image saved to cv_challenge/denoised_images\16cea0e8138ab320.jpg
# Denoised image saved to cv_challenge/denoised_images\173967d903c6e1fd.jpg
# Denoised image saved to cv_challenge/denoised_images\1751ffe68fdbd2d4.jpg
# Denoised image saved to cv_challenge/denoised_images\1768c2f469d6e2c9.jpg
# Denoised image saved to cv_challenge/denoised_images\17708afd7660980a.jpg
# Denoised image saved to cv_challenge/denoised_images\1774705a2d24365b.jpg
# Denoised image saved to cv_challenge/denoised_images\178e58b18cd35045.jpg
# Denoised image saved to cv_challenge/denoised_images\179a2cd94883d529.jpg
# Denoised image saved to cv_challenge/denoised_images\17ab20ba9372dfc0.jpg
# Denoised image saved to cv_challenge/denoised_images\17f6edc3f53dae04.jpg
# Denoised image saved to cv_challenge/denoised_images\17ff149fb0b4f356.jpg
# Denoised image saved to cv_challenge/denoised_images\1813ae28b84caea4.jpg
# Denoised image saved to cv_challenge/denoised_images\183f98c58e2c22f3.jpg
# Denoised image saved to cv_challenge/denoised_images\185c7b0586965647.jpg
# Denoised image saved to cv_challenge/denoised_images\1871e6dbf737bdc9.jpg
# Denoised image saved to cv_challenge/denoised_images\1880c4dc32a4665e.jpg
# Denoised image saved to cv_challenge/denoised_images\1882a6a85cdd8b30.jpg
# Denoised image saved to cv_challenge/denoised_images\188c978dd1f6c289.jpg
# Denoised image saved to cv_challenge/denoised_images\18912bd404188282.jpg
# Denoised image saved to cv_challenge/denoised_images\189255f6ac4eb66b.jpg
# Denoised image saved to cv_challenge/denoised_images\189a6a4d2b3014c8.jpg
# Denoised image saved to cv_challenge/denoised_images\18b3cfa8bc2f7b09.jpg
# Denoised image saved to cv_challenge/denoised_images\18bd9f5d67c34aa8.jpg
# Denoised image saved to cv_challenge/denoised_images\18d53793f7842c2a.jpg
# Denoised image saved to cv_challenge/denoised_images\18dd27022c7141b1.jpg
# Denoised image saved to cv_challenge/denoised_images\190172ace7746279.jpg
# Denoised image saved to cv_challenge/denoised_images\190a44f1e33a86cf.jpg
# Denoised image saved to cv_challenge/denoised_images\1927b4d137261408.jpg
# Denoised image saved to cv_challenge/denoised_images\192f033e14132062.jpg
# Denoised image saved to cv_challenge/denoised_images\193bf72eb8776056.jpg
# Denoised image saved to cv_challenge/denoised_images\19715393750c278b.jpg
# Denoised image saved to cv_challenge/denoised_images\19989d82a51d3bcd.jpg
# Denoised image saved to cv_challenge/denoised_images\19cccbfe8daf8ed4.jpg
# Denoised image saved to cv_challenge/denoised_images\19d98d8ee1d735a7.jpg
# Denoised image saved to cv_challenge/denoised_images\1a0ba37806171e85.jpg
# Denoised image saved to cv_challenge/denoised_images\1a38e93773fee9fb.jpg
# Denoised image saved to cv_challenge/denoised_images\1a4ccaed60d695eb.jpg
# Denoised image saved to cv_challenge/denoised_images\1a6b433e34bc9a9d.jpg
# Denoised image saved to cv_challenge/denoised_images\1a6c830fc871d21a.jpg
# Denoised image saved to cv_challenge/denoised_images\1a85c97dc8b3f6a1.jpg
# Denoised image saved to cv_challenge/denoised_images\1a8a90676e40da26.jpg
# Denoised image saved to cv_challenge/denoised_images\1ab901039c1c7950.jpg
# Denoised image saved to cv_challenge/denoised_images\1ac5d385313e414b.jpg
# Denoised image saved to cv_challenge/denoised_images\1acade48e30258c8.jpg
# Denoised image saved to cv_challenge/denoised_images\1acbab3967fe133b.jpg
# Denoised image saved to cv_challenge/denoised_images\1acc40852f90aa76.jpg
# Denoised image saved to cv_challenge/denoised_images\1ad9ed5392307687.jpg
# Denoised image saved to cv_challenge/denoised_images\1b45268518d29b07.jpg
# Denoised image saved to cv_challenge/denoised_images\1b5039c18de0c674.jpg
# Denoised image saved to cv_challenge/denoised_images\1b7d7bfb252d66f9.jpg
# Denoised image saved to cv_challenge/denoised_images\1b808e977d7299f9.jpg
# Denoised image saved to cv_challenge/denoised_images\1b8e376917bc35ce.jpg
# Denoised image saved to cv_challenge/denoised_images\1b947bc0edb568b4.jpg
# Denoised image saved to cv_challenge/denoised_images\1ba7449285ff620b.jpg
# Denoised image saved to cv_challenge/denoised_images\1bb537e6b94b3f45.jpg
# Denoised image saved to cv_challenge/denoised_images\1bb6d7110cdfc3e2.jpg
# Denoised image saved to cv_challenge/denoised_images\1bbf2e0ac36b9f42.jpg
# Denoised image saved to cv_challenge/denoised_images\1bd30eb70d45631b.jpg
# Denoised image saved to cv_challenge/denoised_images\1be21d6d633d2fd2.jpg
# Denoised image saved to cv_challenge/denoised_images\1c43b2800853a234.jpg
# Denoised image saved to cv_challenge/denoised_images\1c52170a4ee28dbb.jpg
# Denoised image saved to cv_challenge/denoised_images\1c5bb3ae72e3e504.jpg
# Denoised image saved to cv_challenge/denoised_images\1c6ae69790e0b81e.jpg
# Denoised image saved to cv_challenge/denoised_images\1c8bb84432130656.jpg
# Denoised image saved to cv_challenge/denoised_images\1c998a55d06802fd.jpg
# Denoised image saved to cv_challenge/denoised_images\1c9a4401ee709336.jpg
# Denoised image saved to cv_challenge/denoised_images\1cdce942c6dc2a9d.jpg
# Denoised image saved to cv_challenge/denoised_images\1d06929019c52691.jpg
# Denoised image saved to cv_challenge/denoised_images\1d2edb4d479d6a5d.jpg
# Denoised image saved to cv_challenge/denoised_images\1d348ea54f14a477.jpg
# Denoised image saved to cv_challenge/denoised_images\1d3680ff648085f8.jpg
# Denoised image saved to cv_challenge/denoised_images\1d50946bd454ac2e.jpg
# Denoised image saved to cv_challenge/denoised_images\1d51d5f0f1cf9f5d.jpg
# Denoised image saved to cv_challenge/denoised_images\1d7dde7dc94df6a6.jpg
# Denoised image saved to cv_challenge/denoised_images\1d80aca90d37a369.jpg
# Denoised image saved to cv_challenge/denoised_images\1d992d99f9029ba5.jpg
# Denoised image saved to cv_challenge/denoised_images\1db9948726a4e54c.jpg
# Denoised image saved to cv_challenge/denoised_images\1dba741efa983591.jpg
# Denoised image saved to cv_challenge/denoised_images\1dbee405b7797d67.jpg
# Denoised image saved to cv_challenge/denoised_images\1dcb8e3b09cc48b4.jpg
# Denoised image saved to cv_challenge/denoised_images\1dfce34ac940049d.jpg
# Denoised image saved to cv_challenge/denoised_images\1e1bb5109fa84944.jpg
# Denoised image saved to cv_challenge/denoised_images\1e4e41d0390179b2.jpg
# Denoised image saved to cv_challenge/denoised_images\1e5d739d49fa4321.jpg
# Denoised image saved to cv_challenge/denoised_images\1e5d990b03a4f231.jpg
# Denoised image saved to cv_challenge/denoised_images\1e5e16337b85dbc5.jpg
# Denoised image saved to cv_challenge/denoised_images\1e70f33017938358.jpg
# Denoised image saved to cv_challenge/denoised_images\1e7990ef09c250d0.jpg
# Denoised image saved to cv_challenge/denoised_images\1eb76fad8c66761a.jpg
# Denoised image saved to cv_challenge/denoised_images\1ebeda860d3a287f.jpg
# Denoised image saved to cv_challenge/denoised_images\1ec94cb9a2575262.jpg
# Denoised image saved to cv_challenge/denoised_images\1ec9764d52735fb2.jpg
# Denoised image saved to cv_challenge/denoised_images\1efca93753690930.jpg
# Denoised image saved to cv_challenge/denoised_images\1f193033ff3bfa6e.jpg
# Denoised image saved to cv_challenge/denoised_images\1f40e905a531d54f.jpg
# Denoised image saved to cv_challenge/denoised_images\1f4911a0ffc360c1.jpg
# Denoised image saved to cv_challenge/denoised_images\1f515ac075c236f6.jpg
# Denoised image saved to cv_challenge/denoised_images\1f5f0b704c5daf78.jpg
# Denoised image saved to cv_challenge/denoised_images\1f6d185789637715.jpg
# Denoised image saved to cv_challenge/denoised_images\1f79719f611f8200.jpg
# Denoised image saved to cv_challenge/denoised_images\1fabb54270ed69d4.jpg
# Denoised image saved to cv_challenge/denoised_images\1fb2c9fb03cebf17.jpg
# Denoised image saved to cv_challenge/denoised_images\1fbe8682aec6fe42.jpg
# Denoised image saved to cv_challenge/denoised_images\1fe42fadc6864b4d.jpg
# Denoised image saved to cv_challenge/denoised_images\1fe94ce180b093b7.jpg
# Denoised image saved to cv_challenge/denoised_images\200eaf17af79b1f3.jpg
# Denoised image saved to cv_challenge/denoised_images\201706b4bb7ce8ed.jpg
# Denoised image saved to cv_challenge/denoised_images\2037caa0bab5a1b3.jpg
# Denoised image saved to cv_challenge/denoised_images\203c8ca385e06dde.jpg
# Denoised image saved to cv_challenge/denoised_images\20488aeb2c524b39.jpg
# Denoised image saved to cv_challenge/denoised_images\20754dcbca2aaaa0.jpg
# Denoised image saved to cv_challenge/denoised_images\208a846e74340ebd.jpg
# Denoised image saved to cv_challenge/denoised_images\20a244cbfa552f9a.jpg
# Denoised image saved to cv_challenge/denoised_images\20be57c076c9136e.jpg
# Denoised image saved to cv_challenge/denoised_images\20c4d87dd513d951.jpg
# Denoised image saved to cv_challenge/denoised_images\20d2b2669a88eb37.jpg
# Denoised image saved to cv_challenge/denoised_images\2116515a1061933a.jpg
# Denoised image saved to cv_challenge/denoised_images\21226439da551c4a.jpg
# Denoised image saved to cv_challenge/denoised_images\214a647d9134c161.jpg
# Denoised image saved to cv_challenge/denoised_images\214fa42e99015c60.jpg
# Denoised image saved to cv_challenge/denoised_images\2151ee0c994c9423.jpg
# Denoised image saved to cv_challenge/denoised_images\215900568fcb6f12.jpg
# Denoised image saved to cv_challenge/denoised_images\2191c4bb2013b976.jpg
# Denoised image saved to cv_challenge/denoised_images\21b4bb9973d1a078.jpg
# Denoised image saved to cv_challenge/denoised_images\21f77f7a6a9d8754.jpg
# Denoised image saved to cv_challenge/denoised_images\220a586c2501bd4a.jpg
# Denoised image saved to cv_challenge/denoised_images\223f5e290fe98fd0.jpg
# Denoised image saved to cv_challenge/denoised_images\2272fc2dd41b4394.jpg
# Denoised image saved to cv_challenge/denoised_images\22c1ba18e0dc3bae.jpg
# Denoised image saved to cv_challenge/denoised_images\22d1bb69d10ac9d2.jpg
# Denoised image saved to cv_challenge/denoised_images\22dc0568d4c56907.jpg
# Denoised image saved to cv_challenge/denoised_images\22f636ff7d0692ce.jpg
# Denoised image saved to cv_challenge/denoised_images\22f8d8a6aa894258.jpg
# Denoised image saved to cv_challenge/denoised_images\2309b3bf7fbc766d.jpg
# Denoised image saved to cv_challenge/denoised_images\2314a77bf114c865.jpg
# Denoised image saved to cv_challenge/denoised_images\2315e66043df20e9.jpg
# Denoised image saved to cv_challenge/denoised_images\2356c559dbc775ab.jpg
# Denoised image saved to cv_challenge/denoised_images\2358244762f08b64.jpg
# Denoised image saved to cv_challenge/denoised_images\2368e0594474eb68.jpg
# Denoised image saved to cv_challenge/denoised_images\238ba1e680031526.jpg
# Denoised image saved to cv_challenge/denoised_images\238e09e04d7b32cb.jpg
# Denoised image saved to cv_challenge/denoised_images\2392253d19b22e63.jpg
# Denoised image saved to cv_challenge/denoised_images\2393beca89584d1b.jpg
# Denoised image saved to cv_challenge/denoised_images\2394b085e2f8056a.jpg
# Denoised image saved to cv_challenge/denoised_images\23c8dd42cd28c09b.jpg
# Denoised image saved to cv_challenge/denoised_images\23e9a81fd7666ec8.jpg
# Denoised image saved to cv_challenge/denoised_images\2409040a1227d283.jpg
# Denoised image saved to cv_challenge/denoised_images\241a5b2b45b0e16a.jpg
# Denoised image saved to cv_challenge/denoised_images\243b2b94d769833f.jpg
# Denoised image saved to cv_challenge/denoised_images\243c2862de89d302.jpg
# Denoised image saved to cv_challenge/denoised_images\244d359e3e06f107.jpg
# Denoised image saved to cv_challenge/denoised_images\2458ebca45ff00d1.jpg
# Denoised image saved to cv_challenge/denoised_images\24662365e4f67d54.jpg
# Denoised image saved to cv_challenge/denoised_images\24743f05ab3fdad2.jpg
# Denoised image saved to cv_challenge/denoised_images\247b49ccb394e73e.jpg
# Denoised image saved to cv_challenge/denoised_images\2490023d9af20f09.jpg
# Denoised image saved to cv_challenge/denoised_images\24b0b8212e12ed3e.jpg
# Denoised image saved to cv_challenge/denoised_images\24c56bd787b98ecc.jpg
# Denoised image saved to cv_challenge/denoised_images\24f8406f0853c351.jpg
# Denoised image saved to cv_challenge/denoised_images\24fa58d4d4921dcc.jpg
# Denoised image saved to cv_challenge/denoised_images\25100f6edd324f57.jpg
# Denoised image saved to cv_challenge/denoised_images\2510495a022ccc95.jpg
# Denoised image saved to cv_challenge/denoised_images\2519f09dbe275482.jpg
# Denoised image saved to cv_challenge/denoised_images\2523c2a95443aa2f.jpg
# Denoised image saved to cv_challenge/denoised_images\2525474beadeadf3.jpg
# Denoised image saved to cv_challenge/denoised_images\253d3173f646bd3b.jpg
# Denoised image saved to cv_challenge/denoised_images\254c2b8a4b382c76.jpg
# Denoised image saved to cv_challenge/denoised_images\257b07793fdb7c90.jpg
# Denoised image saved to cv_challenge/denoised_images\258e073a7f65a0a6.jpg
# Denoised image saved to cv_challenge/denoised_images\2599880699093a58.jpg
# Denoised image saved to cv_challenge/denoised_images\25a8d6600d2de937.jpg
# Denoised image saved to cv_challenge/denoised_images\26143bfda03ce73e.jpg
# Denoised image saved to cv_challenge/denoised_images\2631b342138322c9.jpg
# Denoised image saved to cv_challenge/denoised_images\263cbadd4561b548.jpg
# Denoised image saved to cv_challenge/denoised_images\26515f03bb0b81f2.jpg
# Denoised image saved to cv_challenge/denoised_images\266278ebc9732a80.jpg
# Denoised image saved to cv_challenge/denoised_images\267e2c2ec8182f3e.jpg
# Denoised image saved to cv_challenge/denoised_images\269c7c87fedc13a6.jpg
# Denoised image saved to cv_challenge/denoised_images\26ab4b8829cc5a2a.jpg
# Denoised image saved to cv_challenge/denoised_images\26ad74e35d3d6dfb.jpg
# Denoised image saved to cv_challenge/denoised_images\26b346df2a13f1d4.jpg
# Denoised image saved to cv_challenge/denoised_images\26b36adf3d246787.jpg
# Denoised image saved to cv_challenge/denoised_images\26daccac09d64a1d.jpg
# Denoised image saved to cv_challenge/denoised_images\26e9f1aad2314b64.jpg
# Denoised image saved to cv_challenge/denoised_images\2705fef18a6fc02c.jpg
# Denoised image saved to cv_challenge/denoised_images\2756f25f1938558d.jpg
# Denoised image saved to cv_challenge/denoised_images\275aec040aac67af.jpg
# Denoised image saved to cv_challenge/denoised_images\2765541d588e9d97.jpg
# Denoised image saved to cv_challenge/denoised_images\2788f05973ca8a3c.jpg
# Denoised image saved to cv_challenge/denoised_images\279c0046ee09258d.jpg
# Denoised image saved to cv_challenge/denoised_images\27ca5681288973d1.jpg
# Denoised image saved to cv_challenge/denoised_images\27e57d3590292262.jpg
# Denoised image saved to cv_challenge/denoised_images\280eb4c18e0b9422.jpg
# Denoised image saved to cv_challenge/denoised_images\2812bcc200f1412b.jpg
# Denoised image saved to cv_challenge/denoised_images\2817aa40a3404fa9.jpg
# Denoised image saved to cv_challenge/denoised_images\282156286a536ea0.jpg
# Denoised image saved to cv_challenge/denoised_images\2832736591a36cd9.jpg
# Denoised image saved to cv_challenge/denoised_images\2832d2e3cd2f1de2.jpg
# Denoised image saved to cv_challenge/denoised_images\285481c6e36c45c1.jpg
# Denoised image saved to cv_challenge/denoised_images\28681a5c3f618df5.jpg
# Denoised image saved to cv_challenge/denoised_images\28714bcc1a53360f.jpg
# Denoised image saved to cv_challenge/denoised_images\2881e0ad82aac9f0.jpg
# Denoised image saved to cv_challenge/denoised_images\2891229b9d30b4c4.jpg
# Denoised image saved to cv_challenge/denoised_images\28989943f1b47b20.jpg
# Denoised image saved to cv_challenge/denoised_images\2904d3025a18b639.jpg
# Denoised image saved to cv_challenge/denoised_images\291d080cbc815866.jpg
# Denoised image saved to cv_challenge/denoised_images\2952a320e5cbd4db.jpg
# Denoised image saved to cv_challenge/denoised_images\2956f79c00f1d8f4.jpg
# Denoised image saved to cv_challenge/denoised_images\296ac4bb9a572492.jpg
# Denoised image saved to cv_challenge/denoised_images\29742b9f303284da.jpg
# Denoised image saved to cv_challenge/denoised_images\29ab86a8a17eae1d.jpg
# Denoised image saved to cv_challenge/denoised_images\29b1dacefc551213.jpg
# Denoised image saved to cv_challenge/denoised_images\29b735dce9d025f4.jpg
# Denoised image saved to cv_challenge/denoised_images\29cbff2d4f3d697a.jpg
# Denoised image saved to cv_challenge/denoised_images\2a050f0c12b65f65.jpg
# Denoised image saved to cv_challenge/denoised_images\2a3756a7d1438abf.jpg
# Denoised image saved to cv_challenge/denoised_images\2a43ed0df4e40da6.jpg
# Denoised image saved to cv_challenge/denoised_images\2a496895464dbe8e.jpg
# Denoised image saved to cv_challenge/denoised_images\2a8658f83ebe2328.jpg
# Denoised image saved to cv_challenge/denoised_images\2a9be2b6b9c9d47f.jpg
# Denoised image saved to cv_challenge/denoised_images\2ab8833bfea1d55f.jpg
# Denoised image saved to cv_challenge/denoised_images\2ada26cfdb707dea.jpg
# Denoised image saved to cv_challenge/denoised_images\2adc963a2a9727a0.jpg
# Denoised image saved to cv_challenge/denoised_images\2af70bfa910763a3.jpg
# Denoised image saved to cv_challenge/denoised_images\2afe4988ccd3f730.jpg
# Denoised image saved to cv_challenge/denoised_images\2b297137d6d37701.jpg
# Denoised image saved to cv_challenge/denoised_images\2b373f6d6c2bcb07.jpg
# Denoised image saved to cv_challenge/denoised_images\2b422337f4b4d937.jpg
# Denoised image saved to cv_challenge/denoised_images\2ba15d167da0458b.jpg
# Denoised image saved to cv_challenge/denoised_images\2bd1bc42a31397d5.jpg
# Denoised image saved to cv_challenge/denoised_images\2bdb1a2b76e57115.jpg
# Denoised image saved to cv_challenge/denoised_images\2bf43d03514feb47.jpg
# Denoised image saved to cv_challenge/denoised_images\2c03b0813138af83.jpg
# Denoised image saved to cv_challenge/denoised_images\2c771c8fae1ba961.jpg
# Denoised image saved to cv_challenge/denoised_images\2c8b14f45b407f78.jpg
# Denoised image saved to cv_challenge/denoised_images\2c8b45f2981a2119.jpg
# Denoised image saved to cv_challenge/denoised_images\2c9888b449c53d1c.jpg
# Denoised image saved to cv_challenge/denoised_images\2ca0a89cc4bd6b4c.jpg
# Denoised image saved to cv_challenge/denoised_images\2cab10f1deae738e.jpg
# Denoised image saved to cv_challenge/denoised_images\2cbbb185120ce2e0.jpg
# Denoised image saved to cv_challenge/denoised_images\2ccd3eca7d2817b7.jpg
# Denoised image saved to cv_challenge/denoised_images\2d075b49d57a56c7.jpg
# Denoised image saved to cv_challenge/denoised_images\2d19c404e5f61205.jpg
# Denoised image saved to cv_challenge/denoised_images\2d2e3fe1fec169d9.jpg
# Denoised image saved to cv_challenge/denoised_images\2d4612a5829c3a7b.jpg
# Denoised image saved to cv_challenge/denoised_images\2d6585b040a243d1.jpg
# Denoised image saved to cv_challenge/denoised_images\2d8895f44940baa7.jpg
# Denoised image saved to cv_challenge/denoised_images\2da2aad7719bde7b.jpg
# Denoised image saved to cv_challenge/denoised_images\2da2fc72f3155387.jpg
# Denoised image saved to cv_challenge/denoised_images\2db1cf2410df3445.jpg
# Denoised image saved to cv_challenge/denoised_images\2dc695383a0129c9.jpg
# Denoised image saved to cv_challenge/denoised_images\2dde09efb7f999d7.jpg
# Denoised image saved to cv_challenge/denoised_images\2e12621278ce1935.jpg
# Denoised image saved to cv_challenge/denoised_images\2e1d4e9d1aa963eb.jpg
# Denoised image saved to cv_challenge/denoised_images\2e4152b8a4893715.jpg
# Denoised image saved to cv_challenge/denoised_images\2e51d14abe1a4fd9.jpg
# Denoised image saved to cv_challenge/denoised_images\2e75bf13e029c0a9.jpg
# Denoised image saved to cv_challenge/denoised_images\2e801370669382a0.jpg
# Denoised image saved to cv_challenge/denoised_images\2e874119ae337439.jpg
# Denoised image saved to cv_challenge/denoised_images\2e9ca801a8c8d1d6.jpg
# Denoised image saved to cv_challenge/denoised_images\2eb1f0e9324e6e03.jpg
# Denoised image saved to cv_challenge/denoised_images\2eff56812f2f078e.jpg
# Denoised image saved to cv_challenge/denoised_images\2f268cff0d675d95.jpg
# Denoised image saved to cv_challenge/denoised_images\2f29b53e9676bf18.jpg
# Denoised image saved to cv_challenge/denoised_images\2f390042292ddaf0.jpg
# Denoised image saved to cv_challenge/denoised_images\2f4532160cabe0b9.jpg
# Denoised image saved to cv_challenge/denoised_images\2f531d35736c0386.jpg
# Denoised image saved to cv_challenge/denoised_images\2f5e8fa28c38b23f.jpg
# Denoised image saved to cv_challenge/denoised_images\2f6b05381ede0836.jpg
# Denoised image saved to cv_challenge/denoised_images\2f845332f59e225a.jpg
# Denoised image saved to cv_challenge/denoised_images\2f8f87040c080372.jpg
# Denoised image saved to cv_challenge/denoised_images\2f9028f0459b7cf8.jpg
# Denoised image saved to cv_challenge/denoised_images\2fa130609266f33c.jpg
# Denoised image saved to cv_challenge/denoised_images\2fa16fe7ed0b6e97.jpg
# Denoised image saved to cv_challenge/denoised_images\2fd9d5a3916d42d3.jpg
# Denoised image saved to cv_challenge/denoised_images\2fdedea275ad1ff7.jpg
# Denoised image saved to cv_challenge/denoised_images\2fdf5f8a6af6aee6.jpg
# Denoised image saved to cv_challenge/denoised_images\2fe76715340d6607.jpg
# Denoised image saved to cv_challenge/denoised_images\2fea1eae8a874099.jpg
# Denoised image saved to cv_challenge/denoised_images\300d1c4ca6595628.jpg
# Denoised image saved to cv_challenge/denoised_images\300dd34e64d9da12.jpg
# Denoised image saved to cv_challenge/denoised_images\30244a22417db7cb.jpg
# Denoised image saved to cv_challenge/denoised_images\3031e41908c9aedd.jpg
# Denoised image saved to cv_challenge/denoised_images\303240d88b015d02.jpg
# Denoised image saved to cv_challenge/denoised_images\30453465d86d512d.jpg
# Denoised image saved to cv_challenge/denoised_images\3052e90cd0d9deaa.jpg
# Denoised image saved to cv_challenge/denoised_images\306c85f9047ec8d9.jpg
# Denoised image saved to cv_challenge/denoised_images\30a664ef38905cc1.jpg
# Denoised image saved to cv_challenge/denoised_images\30ca0601c56012f9.jpg
# Denoised image saved to cv_challenge/denoised_images\30eba77fb758560e.jpg
# Denoised image saved to cv_challenge/denoised_images\30ed2ed6b5b58c2a.jpg
# Denoised image saved to cv_challenge/denoised_images\30f7f943cd13cadc.jpg
# Denoised image saved to cv_challenge/denoised_images\30fa084ccfce6eef.jpg
# Denoised image saved to cv_challenge/denoised_images\30fca194bbbf8e09.jpg
# Denoised image saved to cv_challenge/denoised_images\310baa9589187970.jpg
# Denoised image saved to cv_challenge/denoised_images\312899f2c122e94e.jpg
# Denoised image saved to cv_challenge/denoised_images\313f7f0ec1b28505.jpg
# Denoised image saved to cv_challenge/denoised_images\3157cbb043f66985.jpg
# Denoised image saved to cv_challenge/denoised_images\315cd62bf5044ed2.jpg
# Denoised image saved to cv_challenge/denoised_images\316209cfc3ed8d2f.jpg
# Denoised image saved to cv_challenge/denoised_images\316fa3f17b5d5675.jpg
# Denoised image saved to cv_challenge/denoised_images\31714e371efb0ada.jpg
# Denoised image saved to cv_challenge/denoised_images\318390bc227187f5.jpg
# Denoised image saved to cv_challenge/denoised_images\31cae0b336906cc4.jpg
# Denoised image saved to cv_challenge/denoised_images\31d353c07abbb39c.jpg
# Denoised image saved to cv_challenge/denoised_images\31dc25167c071e7f.jpg
# Denoised image saved to cv_challenge/denoised_images\31e1538e805f11f8.jpg
# Denoised image saved to cv_challenge/denoised_images\31e4d91f308aad9a.jpg
# Denoised image saved to cv_challenge/denoised_images\322373ff9187b892.jpg
# Denoised image saved to cv_challenge/denoised_images\3226133d8f839824.jpg
# Denoised image saved to cv_challenge/denoised_images\32350302aebce029.jpg
# Denoised image saved to cv_challenge/denoised_images\3236448acc2c94de.jpg
# Denoised image saved to cv_challenge/denoised_images\3240aa956fe149a9.jpg
# Denoised image saved to cv_challenge/denoised_images\324fec55bf36d535.jpg
# Denoised image saved to cv_challenge/denoised_images\325a23a80557c0f1.jpg
# Denoised image saved to cv_challenge/denoised_images\32734c4172acc83e.jpg
# Denoised image saved to cv_challenge/denoised_images\32864b66c1db5043.jpg
# Denoised image saved to cv_challenge/denoised_images\3288b3bcb32724b4.jpg
# Denoised image saved to cv_challenge/denoised_images\32b8475aa0122549.jpg
# Denoised image saved to cv_challenge/denoised_images\32bdb23799758ad2.jpg
# Denoised image saved to cv_challenge/denoised_images\32c39eef75d596a3.jpg
# Denoised image saved to cv_challenge/denoised_images\3301f21279dd0302.jpg
# Denoised image saved to cv_challenge/denoised_images\331c07b33ca74a18.jpg
# Denoised image saved to cv_challenge/denoised_images\331f896502673b42.jpg
# Denoised image saved to cv_challenge/denoised_images\33516a0fd6bbed4c.jpg
# Denoised image saved to cv_challenge/denoised_images\336bf1628c3dcefb.jpg
# Denoised image saved to cv_challenge/denoised_images\3373014a56fb3675.jpg
# Denoised image saved to cv_challenge/denoised_images\337bad494e81ae58.jpg
# Denoised image saved to cv_challenge/denoised_images\33b3c8e82347cbb4.jpg
# Denoised image saved to cv_challenge/denoised_images\33c667f4a3404d9a.jpg
# Denoised image saved to cv_challenge/denoised_images\33d46c16b81fae9d.jpg
# Denoised image saved to cv_challenge/denoised_images\33dc33929cac108e.jpg
# Denoised image saved to cv_challenge/denoised_images\33fa323637b9f761.jpg
# Denoised image saved to cv_challenge/denoised_images\340a4e360ac91d35.jpg
# Denoised image saved to cv_challenge/denoised_images\343ca3d3a7ae4072.jpg
# Denoised image saved to cv_challenge/denoised_images\3444606b071da357.jpg
# Denoised image saved to cv_challenge/denoised_images\34555085897bf79a.jpg
# Denoised image saved to cv_challenge/denoised_images\34634c002d20b79f.jpg
# Denoised image saved to cv_challenge/denoised_images\347866ba1a932f12.jpg
# Denoised image saved to cv_challenge/denoised_images\347fa252db2e49dc.jpg
# Denoised image saved to cv_challenge/denoised_images\34899312d04641fc.jpg
# Denoised image saved to cv_challenge/denoised_images\349747686e42e189.jpg
# Denoised image saved to cv_challenge/denoised_images\34a282f9b1d637ab.jpg
# Denoised image saved to cv_challenge/denoised_images\34b764fa9eff8b54.jpg
# Denoised image saved to cv_challenge/denoised_images\34beb54a03e1542f.jpg
# Denoised image saved to cv_challenge/denoised_images\34e3e556cbeb2851.jpg
# Denoised image saved to cv_challenge/denoised_images\34f829fdc151bb6c.jpg
# Denoised image saved to cv_challenge/denoised_images\3500b69d93af20f6.jpg
# Denoised image saved to cv_challenge/denoised_images\35131e3f1dc21609.jpg
# Denoised image saved to cv_challenge/denoised_images\351a98b0751ba7e9.jpg
# Denoised image saved to cv_challenge/denoised_images\352bbf4bea28a956.jpg
# Denoised image saved to cv_challenge/denoised_images\35323a14ead5dd50.jpg
# Denoised image saved to cv_challenge/denoised_images\353606f1d5773b62.jpg
# Denoised image saved to cv_challenge/denoised_images\3551ff70a2ee733b.jpg
# Denoised image saved to cv_challenge/denoised_images\3555e0b5147e713b.jpg
# Denoised image saved to cv_challenge/denoised_images\3556a36795e097f5.jpg
# Denoised image saved to cv_challenge/denoised_images\355e7c8aac6fb4aa.jpg
# Denoised image saved to cv_challenge/denoised_images\356175c28f0dc3da.jpg
# Denoised image saved to cv_challenge/denoised_images\359e1bbe09dc01b1.jpg
# Denoised image saved to cv_challenge/denoised_images\359fab2e1b0ab5e1.jpg
# Denoised image saved to cv_challenge/denoised_images\35b324cdf7cc7545.jpg
# Denoised image saved to cv_challenge/denoised_images\35c5ff3feb2eb136.jpg
# Denoised image saved to cv_challenge/denoised_images\35dd73681edc9676.jpg
# Denoised image saved to cv_challenge/denoised_images\35f6953c2aec900d.jpg
# Denoised image saved to cv_challenge/denoised_images\362620646694ac92.jpg
# Denoised image saved to cv_challenge/denoised_images\363be138e3a257e7.jpg
# Denoised image saved to cv_challenge/denoised_images\365be7920c4f2ea7.jpg
# Denoised image saved to cv_challenge/denoised_images\3676bb8e313dd68a.jpg
# Denoised image saved to cv_challenge/denoised_images\3680db692af79a39.jpg
# Denoised image saved to cv_challenge/denoised_images\36bf8f9173392c5e.jpg
# Denoised image saved to cv_challenge/denoised_images\36d2071e10cb39dd.jpg
# Denoised image saved to cv_challenge/denoised_images\36fe5d4564fe558d.jpg
# Denoised image saved to cv_challenge/denoised_images\370c3e8dcc342b29.jpg
# Denoised image saved to cv_challenge/denoised_images\3712b51ef57adc2a.jpg
# Denoised image saved to cv_challenge/denoised_images\3716e8239efd2f4b.jpg
# Denoised image saved to cv_challenge/denoised_images\3718ddbad5ac13a7.jpg
# Denoised image saved to cv_challenge/denoised_images\3726abe102190f87.jpg
# Denoised image saved to cv_challenge/denoised_images\373c12dc3692758d.jpg
# Denoised image saved to cv_challenge/denoised_images\37516d8801aa3a04.jpg
# Denoised image saved to cv_challenge/denoised_images\375642f60cee4d07.jpg
# ...
# Denoised image saved to cv_challenge/denoised_images\f003f51370a50c93.jpg
# Denoised image saved to cv_challenge/denoised_images\f00899924afb0d57.jpg
# Denoised image saved to cv_challenge/denoised_images\f0231abdaf73d007.jpg
# Denoised image saved to cv_challenge/denoised_images\f02840648bee247d.jpg
# Denoised image saved to cv_challenge/denoised_images\f04b1c2e6ec6b359.jpg
# Denoised image saved to cv_challenge/denoised_images\f06fefb3abfc9877.jpg
# Denoised image saved to cv_challenge/denoised_images\f08aba0820e3ced2.jpg
# Denoised image saved to cv_challenge/denoised_images\f08dd09abe9f17a5.jpg
# Denoised image saved to cv_challenge/denoised_images\f0c5a628e887deae.jpg
# Denoised image saved to cv_challenge/denoised_images\f0c99030ede49938.jpg
# Denoised image saved to cv_challenge/denoised_images\f0cb4c15818227fd.jpg
# Denoised image saved to cv_challenge/denoised_images\f0d149ab498b07df.jpg
# Denoised image saved to cv_challenge/denoised_images\f0db66f90ef8b655.jpg
# Denoised image saved to cv_challenge/denoised_images\f0f8f8cae2aa4f91.jpg
# Denoised image saved to cv_challenge/denoised_images\f10b09c552e128cc.jpg
# Denoised image saved to cv_challenge/denoised_images\f11814e85298b3ac.jpg
# Denoised image saved to cv_challenge/denoised_images\f11c8a9d1deb02c5.jpg
# Denoised image saved to cv_challenge/denoised_images\f13748d04e3589c2.jpg
# Denoised image saved to cv_challenge/denoised_images\f13b67ad52a70ca7.jpg
# Denoised image saved to cv_challenge/denoised_images\f13fb76a32b5be07.jpg
# Denoised image saved to cv_challenge/denoised_images\f14ccbf7e4c723bb.jpg
# Denoised image saved to cv_challenge/denoised_images\f152777ac6b9d3d3.jpg
# Denoised image saved to cv_challenge/denoised_images\f1554aabb2475540.jpg
# Denoised image saved to cv_challenge/denoised_images\f161158faad59821.jpg
# Denoised image saved to cv_challenge/denoised_images\f17f554666ca12ff.jpg
# Denoised image saved to cv_challenge/denoised_images\f218255cdf7e042d.jpg
# Denoised image saved to cv_challenge/denoised_images\f21f5243a3a03a5c.jpg
# Denoised image saved to cv_challenge/denoised_images\f2292ed35e627740.jpg
# Denoised image saved to cv_challenge/denoised_images\f284aab952c379c0.jpg
# Denoised image saved to cv_challenge/denoised_images\f284ce9d728b7b8c.jpg
# Denoised image saved to cv_challenge/denoised_images\f28f000c0b922231.jpg
# Denoised image saved to cv_challenge/denoised_images\f2b00d49e912c28b.jpg
# Denoised image saved to cv_challenge/denoised_images\f2bb6c9e051cd674.jpg
# Denoised image saved to cv_challenge/denoised_images\f2c1497ba33c3589.jpg
# Denoised image saved to cv_challenge/denoised_images\f2c3ec51930a24e6.jpg
# Denoised image saved to cv_challenge/denoised_images\f2dc5e9b6536a88e.jpg
# Denoised image saved to cv_challenge/denoised_images\f2e3d8d512fe5af9.jpg
# Denoised image saved to cv_challenge/denoised_images\f2ee0c899d84051d.jpg
# Denoised image saved to cv_challenge/denoised_images\f2efb6c6782737af.jpg
# Denoised image saved to cv_challenge/denoised_images\f31ab8907d7a62f1.jpg
# Denoised image saved to cv_challenge/denoised_images\f326c0e7f5a18d69.jpg
# Denoised image saved to cv_challenge/denoised_images\f32e862bb527e02b.jpg
# Denoised image saved to cv_challenge/denoised_images\f33f5aba0c140e31.jpg
# Denoised image saved to cv_challenge/denoised_images\f3476472b668cf41.jpg
# Denoised image saved to cv_challenge/denoised_images\f394c1986a58d9a6.jpg
# Denoised image saved to cv_challenge/denoised_images\f39c5eae13108c66.jpg
# Denoised image saved to cv_challenge/denoised_images\f3c59a4be5c55e39.jpg
# Denoised image saved to cv_challenge/denoised_images\f3c5ec9257a244b4.jpg
# Denoised image saved to cv_challenge/denoised_images\f3cf0f201bcd9dd8.jpg
# Denoised image saved to cv_challenge/denoised_images\f3d6ee3a1a6be165.jpg
# Denoised image saved to cv_challenge/denoised_images\f3dd12ab5ef92b2d.jpg
# Denoised image saved to cv_challenge/denoised_images\f3f2a7c21eae3dca.jpg
# Denoised image saved to cv_challenge/denoised_images\f416d903c6d85dd7.jpg
# Denoised image saved to cv_challenge/denoised_images\f4292b3af04a36e9.jpg
# Denoised image saved to cv_challenge/denoised_images\f42e74a589ea5a40.jpg
# Denoised image saved to cv_challenge/denoised_images\f467e17bbab8c38c.jpg
# Denoised image saved to cv_challenge/denoised_images\f474745a871da7ba.jpg
# Denoised image saved to cv_challenge/denoised_images\f4a3d0a04cda84fe.jpg
# Denoised image saved to cv_challenge/denoised_images\f4befaace327f3aa.jpg
# Denoised image saved to cv_challenge/denoised_images\f4d0744845c5a8a2.jpg
# Denoised image saved to cv_challenge/denoised_images\f4f3eac261c6a77a.jpg
# Denoised image saved to cv_challenge/denoised_images\f4f5ac16a14bb916.jpg
# Denoised image saved to cv_challenge/denoised_images\f4f7753dc2bfb99b.jpg
# Denoised image saved to cv_challenge/denoised_images\f4fa9e366fdfafe7.jpg
# Denoised image saved to cv_challenge/denoised_images\f51a904283fc6f60.jpg
# Denoised image saved to cv_challenge/denoised_images\f531310cc3b49735.jpg
# Denoised image saved to cv_challenge/denoised_images\f53c9b465694f2a7.jpg
# Denoised image saved to cv_challenge/denoised_images\f548b18f9c2f1732.jpg
# Denoised image saved to cv_challenge/denoised_images\f5518cc24cad0e85.jpg
# Denoised image saved to cv_challenge/denoised_images\f56f416febae1730.jpg
# Denoised image saved to cv_challenge/denoised_images\f579bf00a38d8eba.jpg
# Denoised image saved to cv_challenge/denoised_images\f582033c5dfcf3b6.jpg
# Denoised image saved to cv_challenge/denoised_images\f58396ee9922d461.jpg
# Denoised image saved to cv_challenge/denoised_images\f5ac2d892aae4690.jpg
# Denoised image saved to cv_challenge/denoised_images\f5af0d45a1bfabeb.jpg
# Denoised image saved to cv_challenge/denoised_images\f5c3333e0b63b205.jpg
# Denoised image saved to cv_challenge/denoised_images\f5e808667c1a793f.jpg
# Denoised image saved to cv_challenge/denoised_images\f6086302c6d317d2.jpg
# Denoised image saved to cv_challenge/denoised_images\f61c2eb39b97f682.jpg
# Denoised image saved to cv_challenge/denoised_images\f62f951c90fc7c94.jpg
# Denoised image saved to cv_challenge/denoised_images\f633cb1682c13eef.jpg
# Denoised image saved to cv_challenge/denoised_images\f63a7c994dfdbec4.jpg
# Denoised image saved to cv_challenge/denoised_images\f64468fee200de7f.jpg
# Denoised image saved to cv_challenge/denoised_images\f648747bdffbaea0.jpg
# Denoised image saved to cv_challenge/denoised_images\f652c12e67c66c6f.jpg
# Denoised image saved to cv_challenge/denoised_images\f66e519ed6c0e74e.jpg
# Denoised image saved to cv_challenge/denoised_images\f6985a3a9f3907f9.jpg
# Denoised image saved to cv_challenge/denoised_images\f6aac8f80acb4da5.jpg
# Denoised image saved to cv_challenge/denoised_images\f6c815713e2df3ed.jpg
# Denoised image saved to cv_challenge/denoised_images\f6d85544806672fa.jpg
# Denoised image saved to cv_challenge/denoised_images\f742c25b6b4498d6.jpg
# Denoised image saved to cv_challenge/denoised_images\f744ae408a064b4c.jpg
# Denoised image saved to cv_challenge/denoised_images\f7468b650cf5b856.jpg
# Denoised image saved to cv_challenge/denoised_images\f74e037dd9b03f97.jpg
# Denoised image saved to cv_challenge/denoised_images\f75181d81619ced3.jpg
# Denoised image saved to cv_challenge/denoised_images\f76371522c7f066a.jpg
# Denoised image saved to cv_challenge/denoised_images\f7702f3e49fd6af1.jpg
# Denoised image saved to cv_challenge/denoised_images\f771a5dd38328084.jpg
# Denoised image saved to cv_challenge/denoised_images\f78724aeeeee4ba6.jpg
# Denoised image saved to cv_challenge/denoised_images\f79c631de960a742.jpg
# Denoised image saved to cv_challenge/denoised_images\f7af475e307d74ae.jpg
# Denoised image saved to cv_challenge/denoised_images\f7cd80294252c2e5.jpg
# Denoised image saved to cv_challenge/denoised_images\f7ec3bdee254abbf.jpg
# Denoised image saved to cv_challenge/denoised_images\f7f26757a8333561.jpg
# Denoised image saved to cv_challenge/denoised_images\f7f6b0add190a48f.jpg
# Denoised image saved to cv_challenge/denoised_images\f81951fa9908eec2.jpg
# Denoised image saved to cv_challenge/denoised_images\f81f2926e990d373.jpg
# Denoised image saved to cv_challenge/denoised_images\f830778e8769f032.jpg
# Denoised image saved to cv_challenge/denoised_images\f831eba2f22f6104.jpg
# Denoised image saved to cv_challenge/denoised_images\f8349caa92ef7304.jpg
# Denoised image saved to cv_challenge/denoised_images\f83bc9783c06ac3a.jpg
# Denoised image saved to cv_challenge/denoised_images\f8411030a07ff0ef.jpg
# Denoised image saved to cv_challenge/denoised_images\f85a952fe68d9086.jpg
# Denoised image saved to cv_challenge/denoised_images\f867719ca398753f.jpg
# Denoised image saved to cv_challenge/denoised_images\f86bf07a146f6d3d.jpg
# Denoised image saved to cv_challenge/denoised_images\f87a2f7db038dca5.jpg
# Denoised image saved to cv_challenge/denoised_images\f87fdd6c08a4fb1f.jpg
# Denoised image saved to cv_challenge/denoised_images\f8a3a3bffd832fb0.jpg
# Denoised image saved to cv_challenge/denoised_images\f8b8397d810afe6f.jpg
# Denoised image saved to cv_challenge/denoised_images\f8b923cc784b1a01.jpg
# Denoised image saved to cv_challenge/denoised_images\f8d1c4541dbb4e9b.jpg
# Denoised image saved to cv_challenge/denoised_images\f8e1fb97fa382075.jpg
# Denoised image saved to cv_challenge/denoised_images\f8ea5351245901e1.jpg
# Denoised image saved to cv_challenge/denoised_images\f915c7ed2f0da1f0.jpg
# Denoised image saved to cv_challenge/denoised_images\f92e9dbad6f08b68.jpg
# Denoised image saved to cv_challenge/denoised_images\f938a5eacf2ac36e.jpg
# Denoised image saved to cv_challenge/denoised_images\f93a97c7503a74bb.jpg
# Denoised image saved to cv_challenge/denoised_images\f93d4698602a8eb2.jpg
# Denoised image saved to cv_challenge/denoised_images\f95c84c901644f43.jpg
# Denoised image saved to cv_challenge/denoised_images\f966981f06d63c75.jpg
# Denoised image saved to cv_challenge/denoised_images\f966a670b26cd62a.jpg
# Denoised image saved to cv_challenge/denoised_images\f976ea88bbf535fd.jpg
# Denoised image saved to cv_challenge/denoised_images\f97a8de79fdd120a.jpg
# Denoised image saved to cv_challenge/denoised_images\f9903346df187c20.jpg
# Denoised image saved to cv_challenge/denoised_images\f99a546a5539cfbf.jpg
# Denoised image saved to cv_challenge/denoised_images\f9b33baa8cffa5ba.jpg
# Denoised image saved to cv_challenge/denoised_images\f9b7f10291d92853.jpg
# Denoised image saved to cv_challenge/denoised_images\f9b9b6043c0eefed.jpg
# Denoised image saved to cv_challenge/denoised_images\f9c3878f86c0e825.jpg
# Denoised image saved to cv_challenge/denoised_images\f9cb9b8539a0ef96.jpg
# Denoised image saved to cv_challenge/denoised_images\f9d470115a4876d2.jpg
# Denoised image saved to cv_challenge/denoised_images\f9d605a4aaa1e065.jpg
# Denoised image saved to cv_challenge/denoised_images\f9ed7ca844bb4d65.jpg
# Denoised image saved to cv_challenge/denoised_images\f9f4967b642cfa2c.jpg
# Denoised image saved to cv_challenge/denoised_images\fa04e014fc886cc7.jpg
# Denoised image saved to cv_challenge/denoised_images\fa1a9c70401b36ff.jpg
# Denoised image saved to cv_challenge/denoised_images\fa212b3110f72316.jpg
# Denoised image saved to cv_challenge/denoised_images\fa3da6a533092084.jpg
# Denoised image saved to cv_challenge/denoised_images\fa65e00002944172.jpg
# Denoised image saved to cv_challenge/denoised_images\fa8429627ef6680e.jpg
# Denoised image saved to cv_challenge/denoised_images\fa8f5676d4bbee86.jpg
# Denoised image saved to cv_challenge/denoised_images\facf95b02e418894.jpg
# Denoised image saved to cv_challenge/denoised_images\fb059068332067dd.jpg
# Denoised image saved to cv_challenge/denoised_images\fb0cae80fe2ac9fc.jpg
# Denoised image saved to cv_challenge/denoised_images\fb409fca105c958f.jpg
# Denoised image saved to cv_challenge/denoised_images\fb4aab42211eb331.jpg
# Denoised image saved to cv_challenge/denoised_images\fb65504f89749e15.jpg
# Denoised image saved to cv_challenge/denoised_images\fb947536ad14961a.jpg
# Denoised image saved to cv_challenge/denoised_images\fb9924486af9b168.jpg
# Denoised image saved to cv_challenge/denoised_images\fba7d069a683e618.jpg
# Denoised image saved to cv_challenge/denoised_images\fbc858824722982c.jpg
# Denoised image saved to cv_challenge/denoised_images\fbcb7823bbfd6008.jpg
# Denoised image saved to cv_challenge/denoised_images\fbeb1ac3d9311231.jpg
# Denoised image saved to cv_challenge/denoised_images\fc04d15f80736458.jpg
# Denoised image saved to cv_challenge/denoised_images\fc0d6a7ad502cc86.jpg
# Denoised image saved to cv_challenge/denoised_images\fc23b6bc90ba1e39.jpg
# Denoised image saved to cv_challenge/denoised_images\fc2a40463c5fbc62.jpg
# Denoised image saved to cv_challenge/denoised_images\fc2c5f6e5d40ce18.jpg
# Denoised image saved to cv_challenge/denoised_images\fc4e7d28b421674b.jpg
# Denoised image saved to cv_challenge/denoised_images\fc51e2f2a0717743.jpg
# Denoised image saved to cv_challenge/denoised_images\fc63e1023ccc9f3c.jpg
# Denoised image saved to cv_challenge/denoised_images\fc7c9c3aa7fbf1d8.jpg
# Denoised image saved to cv_challenge/denoised_images\fc872debee38eb7d.jpg
# Denoised image saved to cv_challenge/denoised_images\fc9cbd311e6be876.jpg
# Denoised image saved to cv_challenge/denoised_images\fca8ceca321331b7.jpg
# Denoised image saved to cv_challenge/denoised_images\fcefb15c88bee6d2.jpg
# Denoised image saved to cv_challenge/denoised_images\fcf52ea455ca476d.jpg
# Denoised image saved to cv_challenge/denoised_images\fcfecc4c06bd2c97.jpg
# Denoised image saved to cv_challenge/denoised_images\fcff04fc711b6b60.jpg
# Denoised image saved to cv_challenge/denoised_images\fcff9fb09fa61a63.jpg
# Denoised image saved to cv_challenge/denoised_images\fd05687092296548.jpg
# Denoised image saved to cv_challenge/denoised_images\fd1044f7f7a90194.jpg
# Denoised image saved to cv_challenge/denoised_images\fd1049bb59b78775.jpg
# Denoised image saved to cv_challenge/denoised_images\fd1927eb0768a55b.jpg
# Denoised image saved to cv_challenge/denoised_images\fd3841bc60862989.jpg
# Denoised image saved to cv_challenge/denoised_images\fd3ae6bc2ca395bc.jpg
# Denoised image saved to cv_challenge/denoised_images\fd4e92ed4f5c452e.jpg
# Denoised image saved to cv_challenge/denoised_images\fd5307c7a3700629.jpg
# Denoised image saved to cv_challenge/denoised_images\fd539ff686027c0c.jpg
# Denoised image saved to cv_challenge/denoised_images\fd5763814d0dc8cd.jpg
# Denoised image saved to cv_challenge/denoised_images\fd6c4a06eebc95ff.jpg
# Denoised image saved to cv_challenge/denoised_images\fda82cd92fe332e3.jpg
# Denoised image saved to cv_challenge/denoised_images\fdaedda2dc4685a9.jpg
# Denoised image saved to cv_challenge/denoised_images\fdcd392ca7d3ba10.jpg
# Denoised image saved to cv_challenge/denoised_images\fdd0f05e0d323a99.jpg
# Denoised image saved to cv_challenge/denoised_images\fe01b41b39d90c5d.jpg
# Denoised image saved to cv_challenge/denoised_images\fe36c0fd5f50924f.jpg
# Denoised image saved to cv_challenge/denoised_images\fe5352b29f25d6fe.jpg
# Denoised image saved to cv_challenge/denoised_images\fe86b7318956bf3f.jpg
# Denoised image saved to cv_challenge/denoised_images\feae829823ba76c0.jpg
# Denoised image saved to cv_challenge/denoised_images\fecc824e850e1f41.jpg
# Denoised image saved to cv_challenge/denoised_images\fedb4785b031363f.jpg
# Denoised image saved to cv_challenge/denoised_images\fef1651e402b9db2.jpg
# Denoised image saved to cv_challenge/denoised_images\fef6fe429365b6f6.jpg
# Denoised image saved to cv_challenge/denoised_images\ff2f82db799bf247.jpg
# Denoised image saved to cv_challenge/denoised_images\ff31c0f0fdc21455.jpg
# Denoised image saved to cv_challenge/denoised_images\ff361d65c5d26fea.jpg
# Denoised image saved to cv_challenge/denoised_images\ff611b061f5ceb6d.jpg
# Denoised image saved to cv_challenge/denoised_images\ff6a9e516d685849.jpg
# Denoised image saved to cv_challenge/denoised_images\ff70a399a80c1c96.jpg
# Denoised image saved to cv_challenge/denoised_images\ffae8e4907100e60.jpg
# Denoised image saved to cv_challenge/denoised_images\ffb4b6f619fb60ea.jpg
# Denoised image saved to cv_challenge/denoised_images\ffb54299b1ad4159.jpg
# Denoised image saved to cv_challenge/denoised_images\ffc2c91dff8cf2c0.jpg
# Denoised image saved to cv_challenge/denoised_images\ffc4e330a5353a2a.jpg
# Denoised image saved to cv_challenge/denoised_images\ffc71fed753d90c1.jpg

# %%
torch.save(model.state_dict(), 'CuDNN_5.pth')
